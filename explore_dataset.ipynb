# %%
import pandas as pd

# Încarcă fișierul CSV
df = pd.read_csv("dataset/hfi_cc_2022.csv")

# Afișează dimensiuni și primele rânduri
print("Shape:", df.shape)
df.head()
# Out:
# Shape: (3465, 141)
#    year  countries                         region  hf_score  hf_rank  \
# 0  2020    Albania                 Eastern Europe      7.67     47.0
# 1  2020    Algeria     Middle East & North Africa      5.13    154.0
# 2  2020     Angola             Sub-Saharan Africa      5.97    122.0
# 3  2020  Argentina  Latin America & the Caribbean      6.99     74.0
# 4  2020    Armenia        Caucasus & Central Asia      8.14     26.0
#
#    hf_quartile  pf_rol_procedural  pf_rol_civil  pf_rol_criminal  pf_rol_vdem  \
# 0          2.0           5.903741      4.725831         4.047825     7.194198
# 1          4.0           4.913311      5.503872         4.254187     5.461189
# 2          3.0           2.773262      4.352009         3.478950     5.306695
# 3          2.0           6.824288      5.679943         4.218635     6.748978
# 4          1.0                NaN           NaN              NaN     7.204175
#
# ...

# %%
# Informații generale
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3465 entries, 0 to 3464
# Columns: 141 entries, year to ef_rank
# dtypes: float64(133), int64(3), object(5)
# memory usage: 3.7+ MB

# %%
# Coloane cu valori lipsă
missing = df.isnull().sum()
missing[missing > 0].sort_values(ascending=False)
# Out:
# pf_identity_inheritance_daughters    2548
# pf_identity_inheritance_widows       2548
# pf_rol_criminal                      2075
# pf_rol_civil                         2075
# pf_rol_procedural                    2075
#                                      ...
# pf_religion_freedom_cld                33
# pf_expression_cld                      33
# pf_identity_divorce                    21
# pf_identity                            10
# ef_gender                               6
# Length: 115, dtype: int64

# %%
# Numele tuturor coloanelor
df.columns.to_list()
# Out:
# ['year',
#  'countries',
#  'region',
#  'hf_score',
#  'hf_rank',
#  'hf_quartile',
#  'pf_rol_procedural',
#  'pf_rol_civil',
#  'pf_rol_criminal',
#  'pf_rol_vdem',
#  'pf_rol',
#  'pf_ss_homicide',
#  'pf_ss_homicide_data',
#  'pf_ss_disappearances_disap',
#  'pf_ss_disappearances_violent',
#  'pf_ss_disappearances_violent_data',
#  'pf_ss_disappearances_organized',
#  'pf_ss_disappearances_fatalities',
#  'pf_ss_disappearances_fatalities_data',
#  'pf_ss_disappearances_injuries',
#  'pf_ss_disappearances_injuries_data',
#  'pf_ss_disappearances_torture',
#  'pf_ss_killings',
#  'pf_ss_disappearances',
#  'pf_ss',
#  'pf_movement_vdem_foreign',
#  'pf_movement_vdem_men',
#  'pf_movement_vdem_women',
#  'pf_movement_vdem',
#  'pf_movement_cld',
#  'pf_movement',
#  'pf_religion_freedom_vdem',
#  'pf_religion_freedom_cld',
#  'pf_religion_freedom',
#  'pf_religion_suppression',
#  'pf_religion',
#  'pf_assembly_entry',
#  'pf_assembly_freedom_house',
#  'pf_assembly_freedom_bti',
# ...

# %%
# Un exemplu concret (ex: România)
df[df['countries'] == 'Romania'].T
# Out:
#                                              125             290   \
# year                                         2020            2019
# countries                                 Romania         Romania
# region                             Eastern Europe  Eastern Europe
# hf_score                                     7.89            8.25
# hf_rank                                      38.0            38.0
# ...                                           ...             ...
# ef_regulation_business_compliance         8.17288         8.17288
# ef_regulation_business                   6.564784        6.645015
# ef_regulation                            7.218131        7.518355
# ef_score                                     7.74            7.87
# ef_rank                                      19.0            28.0
#
#                                              455             620   \
# year                                         2018            2017
# ...

# %%
df['region'].value_counts()
# Out:
# region
# Sub-Saharan Africa               945
# Latin America & the Caribbean    546
# Eastern Europe                   462
# Middle East & North Africa       399
# Western Europe                   378
# South Asia                       357
# East Asia                        126
# Caucasus & Central Asia          126
# Oceania                           84
# North America                     42
# Name: count, dtype: int64

# %%
df.describe(include='all')
# Out:
#                year countries              region     hf_score      hf_rank  \
# count   3465.000000      3465                3465  3083.000000  3083.000000
# unique          NaN       165                  10          NaN          NaN
# top             NaN   Albania  Sub-Saharan Africa          NaN          NaN
# freq            NaN        21                 945          NaN          NaN
# mean    2010.000000       NaN                 NaN     7.137230    74.438210
# std        6.056175       NaN                 NaN     1.231567    43.566679
# min     2000.000000       NaN                 NaN     3.150000     1.000000
# 25%     2005.000000       NaN                 NaN     6.210000    37.000000
# 50%     2010.000000       NaN                 NaN     7.230000    74.000000
# 75%     2015.000000       NaN                 NaN     8.180000   110.000000
# max     2020.000000       NaN                 NaN     9.300000   165.000000
#
# ...

# %%
df[['countries', 'hf_score']].sort_values(by='hf_score', ascending=False).head(10)
# Out:
#         countries  hf_score
# 3113  Switzerland      9.30
# 3443  Switzerland      9.29
# 2948  Switzerland      9.28
# 2783  Switzerland      9.26
# 638   Switzerland      9.20
# 3278  Switzerland      9.20
# 473   Switzerland      9.19
# 2453  Switzerland      9.19
# 2288  Switzerland      9.19
# 769   New Zealand      9.18
